# %%
import pandas as pd

from tqdm.notebook import tqdm

# %%
# !ls -l ../data/
# Out:
# total 580592
# -rw-r--r-- 1 textor textor    904039 Apr 17 11:52 appl.csv
# -rw-r--r-- 1 textor textor   6577695 Apr 17 11:52 aum.csv
# -rw-r--r-- 1 textor textor  91636746 Apr 17 11:52 balance.csv
# -rw-r--r-- 1 textor textor   1110765 Apr 17 11:52 client.csv
# -rw-r--r-- 1 textor textor   6686165 Apr 17 11:52 com.csv
# -rw-r--r-- 1 textor textor   7499804 Apr 17 11:52 deals.csv
# -rw-r--r-- 1 textor textor     18979 Apr 17 11:52 dict_mcc.csv
# -rw-r--r-- 1 textor textor   2322389 Apr 17 11:52 funnel.csv
# -rw-r--r-- 1 textor textor  10553763 Apr 17 11:52 payments.csv
# -rw-r--r-- 1 textor textor 467193115 Apr 17 11:52 trxn.csv

# %%
from pathlib import Path

# %%
path_df = Path('../data').rglob('*.csv')
path_df = sorted(path_df)

for path in tqdm(path_df):
    df_name = 'df_' + path.name.rsplit('.', 1)[0]
    vars()[df_name] = pd.read_csv(path)
    print(f'{path} saved to {df_name}; {df_name}.shape = {vars()[df_name].shape}')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# ../data/appl.csv saved to df_appl; df_appl.shape = (12030, 6)
# ../data/aum.csv saved to df_aum; df_aum.shape = (117392, 4)
# ../data/balance.csv saved to df_balance; df_balance.shape = (1194684, 9)
# ../data/client.csv saved to df_client; df_client.shape = (21498, 8)
# ../data/com.csv saved to df_com; df_com.shape = (113055, 10)
# ../data/deals.csv saved to df_deals; df_deals.shape = (109016, 8)
# ../data/dict_mcc.csv saved to df_dict_mcc; df_dict_mcc.shape = (915, 3)
# ../data/funnel.csv saved to df_funnel; df_funnel.shape = (21498, 16)
# ../data/payments.csv saved to df_payments; df_payments.shape = (188068, 4)
# /home/textor/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# ../data/trxn.csv saved to df_trxn; df_trxn.shape = (3035705, 11)

# %%
df_dict_mcc['mcc_category'] = df_dict_mcc['brs_mcc_group'].astype('category').cat.codes
df_dict_mcc.head()
# Out:
#    mcc_cd brs_mcc_group brs_mcc_subgroup  mcc_category
# 0    3658        Travel           Hotels            20
# 1    3659        Travel           Hotels            20
# 2    3660        Travel           Hotels            20
# 3    3661        Travel           Hotels            20
# 4    3662        Travel           Hotels            20

# %%
df_trxn['tran_time'] = pd.to_datetime(df_trxn['tran_time'])
df_trxn['tran_time_day_offset'] = (df_trxn['tran_time'] - df_trxn['tran_time'].min()).dt.days
df_trxn['mcc_cd'] = df_trxn['mcc_cd'].fillna(-1).astype(int)

# %%
df = pd.merge(df_trxn, df_dict_mcc[['mcc_cd', 'mcc_category']], how='left', on='mcc_cd')
df['mcc_category'] = df['mcc_category'].fillna(-1).astype(int)
df.head()
# Out:
#              client_id              card_id           tran_time  tran_amt_rur  \
# 0 -1893104556496814867 -6909844117230568380 2019-07-01 00:00:00        6071.0
# 1 -1893104556496814867 -6909844117230568380 2019-07-29 00:00:00        6071.0
# 2 -1893104556496814867 -6909844117230568380 2019-08-31 00:00:00        7285.0
# 3  6886062013213911831  6527755410945490683 2019-08-14 10:38:33        2428.0
# 4  6886062013213911831  6527755410945490683 2019-07-17 12:27:58        6071.0
#
#    mcc_cd          merchant_cd txn_country     txn_city              tsp_name  \
# 0    6011  3796217713062573289         RUS  N. NOVGOROD  MOLODEZHNYY PR. DEPO
# 1    6011  3796217713062573289         RUS  N. NOVGOROD  MOLODEZHNYY PR. DEPO
# 2    6011  3796217713062573289         RUS  N. NOVGOROD  MOLODEZHNYY PR. DEPO
# 3    6011  -774579209084196290         RUS    RADUZHNYI              TTS SITI
# 4    6011 -7735007003326589238         RUS    RADUZHNYI         ODTS AGANGRAD
#
#                     txn_comment_1 txn_comment_2  tran_time_day_offset  \
# 0  Cash withdrawal through an ATM           NaN                   303
# 1  Cash withdrawal through an ATM           NaN                   331
# 2  Cash withdrawal through an ATM           NaN                   364
# 3  Cash withdrawal through an ATM           NaN                   347
# 4  Cash withdrawal through an ATM           NaN                   319
#
#    mcc_category
# 0             2
# 1             2
# 2             2
# 3             2
# 4             2

# %%
MCC_CODES_RARE = {
    'mcc_cd_-1',
    'mcc_cd_1520',
    'mcc_cd_1711',
    'mcc_cd_1731',
    'mcc_cd_1740',
    'mcc_cd_1750',
    'mcc_cd_1761',
    'mcc_cd_1799',
    'mcc_cd_2741',
    'mcc_cd_2791',
    'mcc_cd_2842',
    'mcc_cd_3007',
    'mcc_cd_3008',
    'mcc_cd_3011',
    'mcc_cd_3015',
    'mcc_cd_3026',
    'mcc_cd_3034',
    'mcc_cd_3042',
    'mcc_cd_3047',
    'mcc_cd_3183',
    'mcc_cd_3217',
    'mcc_cd_3245',
    'mcc_cd_3246',
    'mcc_cd_3301',
    'mcc_cd_3355',
    'mcc_cd_3501',
    'mcc_cd_3502',
    'mcc_cd_3503',
    'mcc_cd_3504',
    'mcc_cd_3509',
    'mcc_cd_3512',
    'mcc_cd_3513',
    'mcc_cd_3530',
    'mcc_cd_3533',
    'mcc_cd_3543',
    'mcc_cd_3553',
    'mcc_cd_3579',
    'mcc_cd_3583',
    'mcc_cd_3598',
    'mcc_cd_3612',
    'mcc_cd_3634',
    'mcc_cd_3640',
    'mcc_cd_3642',
    'mcc_cd_3649',
    'mcc_cd_3665',
    'mcc_cd_3690',
    'mcc_cd_3692',
    'mcc_cd_3710',
    'mcc_cd_3750',
    'mcc_cd_4011',
    'mcc_cd_4119',
    'mcc_cd_4214',
    'mcc_cd_4225',
    'mcc_cd_4411',
    'mcc_cd_4457',
    'mcc_cd_4582',
    'mcc_cd_4722',
    'mcc_cd_4784',
    'mcc_cd_4829',
    'mcc_cd_4899',
    'mcc_cd_5013',
    'mcc_cd_5021',
    'mcc_cd_5044',
    'mcc_cd_5045',
    'mcc_cd_5046',
    'mcc_cd_5047',
    'mcc_cd_5051',
    'mcc_cd_5065',
    'mcc_cd_5072',
    'mcc_cd_5074',
    'mcc_cd_5085',
    'mcc_cd_5094',
    'mcc_cd_5099',
    'mcc_cd_5111',
    'mcc_cd_5122',
    'mcc_cd_5131',
    'mcc_cd_5137',
    'mcc_cd_5139',
    'mcc_cd_5169',
    'mcc_cd_5172',
    'mcc_cd_5192',
    'mcc_cd_5193',
    'mcc_cd_5198',
    'mcc_cd_5199',
    'mcc_cd_5231',
    'mcc_cd_5300',
    'mcc_cd_5309',
    'mcc_cd_5310',
    'mcc_cd_5521',
    'mcc_cd_5531',
    'mcc_cd_5532',
    'mcc_cd_5542',
    'mcc_cd_5551',
    'mcc_cd_5561',
    'mcc_cd_5571',
    'mcc_cd_5599',
    'mcc_cd_5655',
    'mcc_cd_5681',
    'mcc_cd_5697',
    'mcc_cd_5698',
    'mcc_cd_5713',
    'mcc_cd_5718',
    'mcc_cd_5733',
    'mcc_cd_5734',
    'mcc_cd_5735',
    'mcc_cd_5811',
    'mcc_cd_5815',
    'mcc_cd_5817',
    'mcc_cd_5818',
    'mcc_cd_5931',
    'mcc_cd_5932',
    'mcc_cd_5933',
    'mcc_cd_5940',
    'mcc_cd_5946',
    'mcc_cd_5948',
    'mcc_cd_5950',
    'mcc_cd_5960',
    'mcc_cd_5962',
    'mcc_cd_5963',
    'mcc_cd_5965',
    'mcc_cd_5966',
    'mcc_cd_5967',
    'mcc_cd_5968',
    'mcc_cd_5969',
    'mcc_cd_5970',
    'mcc_cd_5971',
    'mcc_cd_5973',
    'mcc_cd_5975',
    'mcc_cd_5976',
    'mcc_cd_5978',
    'mcc_cd_5983',
    'mcc_cd_5994',
    'mcc_cd_5996',
    'mcc_cd_5998',
    'mcc_cd_6050',
    'mcc_cd_6051',
    'mcc_cd_6211',
    'mcc_cd_6513',
    'mcc_cd_6532',
    'mcc_cd_6537',
    'mcc_cd_6540',
    'mcc_cd_7012',
    'mcc_cd_7032',
    'mcc_cd_7033',
    'mcc_cd_7210',
    'mcc_cd_7211',
    'mcc_cd_7216',
    'mcc_cd_7217',
    'mcc_cd_7221',
    'mcc_cd_7251',
    'mcc_cd_7261',
    'mcc_cd_7273',
    'mcc_cd_7277',
    'mcc_cd_7278',
    'mcc_cd_7296',
    'mcc_cd_7297',
    'mcc_cd_7298',
    'mcc_cd_7311',
    'mcc_cd_7333',
    'mcc_cd_7338',
    'mcc_cd_7339',
    'mcc_cd_7349',
    'mcc_cd_7361',
    'mcc_cd_7372',
    'mcc_cd_7375',
    'mcc_cd_7379',
    'mcc_cd_7392',
    'mcc_cd_7393',
    'mcc_cd_7394',
    'mcc_cd_7395',
    'mcc_cd_7399',
    'mcc_cd_742',
    'mcc_cd_7512',
    'mcc_cd_7513',
    'mcc_cd_7519',
    'mcc_cd_7523',
    'mcc_cd_7531',
    'mcc_cd_7534',
    'mcc_cd_7535',
    'mcc_cd_7622',
    'mcc_cd_7623',
    'mcc_cd_7629',
    'mcc_cd_763',
    'mcc_cd_7631',
    'mcc_cd_7641',
    'mcc_cd_7692',
    'mcc_cd_7699',
    'mcc_cd_780',
    'mcc_cd_7829',
    'mcc_cd_7841',
    'mcc_cd_7911',
    'mcc_cd_7929',
    'mcc_cd_7932',
    'mcc_cd_7933',
    'mcc_cd_7941',
    'mcc_cd_7991',
    'mcc_cd_7993',
    'mcc_cd_7994',
    'mcc_cd_7995',
    'mcc_cd_7996',
    'mcc_cd_7998',
    'mcc_cd_7999',
    'mcc_cd_8041',
    'mcc_cd_8042',
    'mcc_cd_8049',
    'mcc_cd_8050',
    'mcc_cd_8071',
    'mcc_cd_8111',
    'mcc_cd_8211',
    'mcc_cd_8220',
    'mcc_cd_8241',
    'mcc_cd_8244',
    'mcc_cd_8249',
    'mcc_cd_8351',
    'mcc_cd_8398',
    'mcc_cd_8641',
    'mcc_cd_8661',
    'mcc_cd_8699',
    'mcc_cd_8734',
    'mcc_cd_8931',
    'mcc_cd_9211',
    'mcc_cd_9223',
    'mcc_cd_9405',
}

MCC_CODES_RARE = {int(e.rsplit('_')[-1]) for e in MCC_CODES_RARE}

df.loc[df['mcc_cd'].isin(MCC_CODES_RARE), 'mcc_cd'] = -1

# %%
df.isna().sum(axis=0)
# Out:
# client_id                     0
# card_id                       0
# tran_time                     0
# tran_amt_rur                  0
# mcc_cd                        0
# merchant_cd                   0
# txn_country                   0
# txn_city                   5385
# tsp_name                   2162
# txn_comment_1                 0
# txn_comment_2           2638786
# tran_time_day_offset          0
# mcc_category                  0
# dtype: int64

# %%
df.groupby('client_id')['card_id'].count().sort_values()[::-1]
# Out:
# client_id
#  8247514152661289191    3101
# -9059132502179716006    2656
#  7922361971867610498    2413
# -7299536715312723669    2322
#  410746725485357352     2318
#                         ...
# -293405486348082812        1
#  5298349669486843184       1
# -6259300834103212263       1
#  7627853032776049183       1
#  840070581335939466        1
# Name: card_id, Length: 11236, dtype: int64

# %%
group = df.groupby('client_id').get_group(7922361971867610498)
group.sort_values(by='tran_time', inplace=True)
group.head()
# Out:
# <ipython-input-11-7ee23a22e0ad>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group.sort_values(by='tran_time', inplace=True)
#                    client_id              card_id           tran_time  \
# 2940363  7922361971867610498 -5021825852986699015 2018-09-01 00:00:00
# 2230234  7922361971867610498 -5021825852986699015 2018-09-01 09:57:00
# 2230251  7922361971867610498 -5021825852986699015 2018-09-01 09:58:06
# 2728463  7922361971867610498 -5021825852986699015 2018-09-01 10:03:03
# 2728514  7922361971867610498 -5021825852986699015 2018-09-01 10:17:53
#
#          tran_amt_rur  mcc_cd          merchant_cd txn_country      txn_city  \
# 2940363          72.0      -1  3967370607447365704         IRL           NaN
# 2230234        6071.0    6011  3967370607447365704         RUS  SANKTPETERBU
# 2230251        6071.0    6011  3967370607447365704         RUS  SANKTPETERBU
# 2728463         284.0    5411  3967370607447365704         RUS  METALLOSTROJ
# 2728514         607.0    5541  1545852325860792925         RUS    SPETERBURG
#
#                 tsp_name                   txn_comment_1  \
# 2940363       ITUNES.COM  Payment for goods and services
# 2230234              ATM  Cash withdrawal through an ATM
# 2230251              ATM  Cash withdrawal through an ATM
# 2728463  UNIVERSAM SEMYA  Payment for goods and services
# 2728514              AZK  Payment for goods and services
#
#                   txn_comment_2  tran_time_day_offset  mcc_category
# 2940363  Purchase payment (web)                     0            12
# 2230234                     NaN                     0             2
# 2230251                     NaN                     0             2
# 2728463                     NaN                     0             9
# 2728514                     NaN                     0             1

# %%
def create_aggregates_amount_by(group, by):
    kd = group.groupby(by)['tran_amt_rur'].agg(['sum', 'count', 'min', 'max', 'std'])
    kd['std'] = kd['std'].fillna(0)
    kd['mean'] = kd['sum'] / kd['count']
    
    features = {}
    
    for col in kd.columns:
        features_ = {kd.index.name + '_' + str(k) + '_amnt_' + col : v
                     for k, v in kd[col].to_dict().items()}
        features.update(features_)
        
    return features


def create_transaction_features(name, group):
    info = {'client_id': name}
    
    group = group.sort_values(by='tran_time')
    
    info['num_transactions'] = group.shape[0]
    
    tran_time_min = group['tran_time'].min()
    tran_time_max = group['tran_time'].max()
    
    info['num_weekofyear'] = group['tran_time'].dt.isocalendar().week.nunique()
    
    info['num_days_tran_diff'] = (tran_time_max - tran_time_min).days
    info['num_days_tran_uniq'] = group['tran_time_day_offset'].nunique()
    info['num_days_tran_median'] = group['tran_time_day_offset'].median()
    info['num_days_tran_max'] = group['tran_time_day_offset'].max()
    info['num_days_tran_std'] = group['tran_time_day_offset'].std()
    
    hour_diff = group['tran_time'].diff().dt.total_seconds() / 3600
    
    info['hour_mean'] = group['tran_time'].dt.hour.mean()
    info['hour_std'] = group['tran_time'].dt.hour.std()
    info['hour_q05'], info['hour_q50'], info['hour_q95'] = \
        group['tran_time'].dt.hour.quantile([0.05, 0.5, 0.95])

    info['hour_diff_q50'] = hour_diff.median()
    info['hour_diff_max'] = hour_diff.max()
    info['hour_diff_std'] = hour_diff.std()
    
    info['weekend_amnt_mean'] = group.loc[group['tran_time'].dt.weekday >= 5, 'tran_amt_rur'].mean()
    info['amnt_q10'], info['amnt_q50'], info['amnt_q95'] = \
        group['tran_amt_rur'].quantile([0.1, 0.5, 0.95])
    
    info['amnt_diff_q10'], info['amnt_diff_q50'], info['amnt_diff_q95'] = \
        group['tran_amt_rur'].diff().quantile([0.1, 0.5, 0.95])
    
    info['num_cards'] = group['card_id'].nunique()
    
    info.update(create_aggregates_amount_by(group, by='mcc_cd'))
    info.update(create_aggregates_amount_by(group, by='mcc_category'))
    
    return info

# %%
create_transaction_features(0, group)
# Out:
# {'client_id': 0,
#  'num_transactions': 2413,
#  'num_weekofyear': 52,
#  'num_days_tran_diff': 364,
#  'num_days_tran_uniq': 362,
#  'num_days_tran_median': 186.0,
#  'num_days_tran_max': 364,
#  'num_days_tran_std': 104.95985063276596,
#  'hour_mean': 13.891007045171985,
#  'hour_std': 5.133230552893014,
#  'hour_q05': 0.0,
#  'hour_q50': 14.0,
#  'hour_q95': 20.0,
#  'hour_diff_q50': 0.8604166666666666,
#  'hour_diff_max': 41.33972222222222,
#  'hour_diff_std': 5.717851412023088,
#  'weekend_amnt_mean': 728.9023668639053,
#  'amnt_q10': 73.0,
#  'amnt_q50': 279.0,
#  'amnt_q95': 2601.6000000000013,
#  'amnt_diff_q10': -977.4999999999999,
#  'amnt_diff_q50': -1.0,
#  'amnt_diff_q95': 1922.4499999999998,
#  'num_cards': 3,
#  'mcc_cd_-1_amnt_sum': 36499.0,
#  'mcc_cd_4111_amnt_sum': 1129.0,
#  'mcc_cd_4112_amnt_sum': 28406.0,
#  'mcc_cd_4121_amnt_sum': 4877.0,
#  'mcc_cd_4215_amnt_sum': 1798.0,
#  'mcc_cd_4812_amnt_sum': 52440.0,
#  'mcc_cd_5200_amnt_sum': 18815.0,
#  'mcc_cd_5211_amnt_sum': 9505.0,
#  'mcc_cd_5311_amnt_sum': 18275.0,
#  'mcc_cd_5331_amnt_sum': 20663.0,
#  'mcc_cd_5399_amnt_sum': 15868.0,
#  'mcc_cd_5411_amnt_sum': 294224.0,
#  'mcc_cd_5422_amnt_sum': 565.0,
#  'mcc_cd_5441_amnt_sum': 3688.0,
#  'mcc_cd_5451_amnt_sum': 1307.0,
#  'mcc_cd_5462_amnt_sum': 2959.0,
#  'mcc_cd_5499_amnt_sum': 35477.0,
#  'mcc_cd_5511_amnt_sum': 8343.0,
#  'mcc_cd_5533_amnt_sum': 40738.0,
#  'mcc_cd_5541_amnt_sum': 120143.0,
#  'mcc_cd_5611_amnt_sum': 134.0,
#  'mcc_cd_5621_amnt_sum': 741.0,
#  'mcc_cd_5641_amnt_sum': 13741.0,
#  'mcc_cd_5651_amnt_sum': 115329.0,
#  'mcc_cd_5661_amnt_sum': 7778.0,
#  'mcc_cd_5691_amnt_sum': 21914.0,
#  'mcc_cd_5699_amnt_sum': 1820.0,
#  'mcc_cd_5712_amnt_sum': 8884.0,
#  'mcc_cd_5719_amnt_sum': 7484.0,
#  'mcc_cd_5722_amnt_sum': 54447.0,
#  'mcc_cd_5732_amnt_sum': 13304.0,
#  'mcc_cd_5812_amnt_sum': 23308.0,
#  'mcc_cd_5813_amnt_sum': 6184.0,
#  'mcc_cd_5814_amnt_sum': 73045.0,
#  'mcc_cd_5912_amnt_sum': 26879.0,
#  'mcc_cd_5921_amnt_sum': 90178.0,
#  'mcc_cd_5942_amnt_sum': 243.0,
#  'mcc_cd_5943_amnt_sum': 168.0,
#  'mcc_cd_5944_amnt_sum': 668.0,
#  'mcc_cd_5945_amnt_sum': 48331.0,
#  'mcc_cd_5947_amnt_sum': 704.0,
#  'mcc_cd_5949_amnt_sum': 3597.0,
#  'mcc_cd_5964_amnt_sum': 1571.0,
#  'mcc_cd_5977_amnt_sum': 32499.0,
#  'mcc_cd_5992_amnt_sum': 4334.0,
#  'mcc_cd_5995_amnt_sum': 2377.0,
#  'mcc_cd_5999_amnt_sum': 11986.0,
#  'mcc_cd_6010_amnt_sum': 1916.0,
#  'mcc_cd_6011_amnt_sum': 410734.0,
#  'mcc_cd_6536_amnt_sum': 82751.0,
#  'mcc_cd_6538_amnt_sum': 14555.0,
#  'mcc_cd_7011_amnt_sum': 2950.0,
#  'mcc_cd_7230_amnt_sum': 2914.0,
#  'mcc_cd_7299_amnt_sum': 243.0,
#  'mcc_cd_7538_amnt_sum': 656.0,
#  'mcc_cd_7542_amnt_sum': 121.0,
#  'mcc_cd_7832_amnt_sum': 1056.0,
#  'mcc_cd_8043_amnt_sum': 2455.0,
#  'mcc_cd_8999_amnt_sum': 1528.0,
#  'mcc_cd_9222_amnt_sum': 1257.0,
#  'mcc_cd_9311_amnt_sum': 1958.0,
#  'mcc_cd_9402_amnt_sum': 129.0,
#  'mcc_cd_-1_amnt_count': 63,
#  'mcc_cd_4111_amnt_count': 19,
#  'mcc_cd_4112_amnt_count': 3,
#  'mcc_cd_4121_amnt_count': 15,
#  'mcc_cd_4215_amnt_count': 2,
#  'mcc_cd_4812_amnt_count': 50,
#  'mcc_cd_5200_amnt_count': 26,
#  'mcc_cd_5211_amnt_count': 37,
#  'mcc_cd_5311_amnt_count': 62,
#  'mcc_cd_5331_amnt_count': 63,
#  'mcc_cd_5399_amnt_count': 12,
#  'mcc_cd_5411_amnt_count': 750,
#  'mcc_cd_5422_amnt_count': 3,
#  'mcc_cd_5441_amnt_count': 20,
#  'mcc_cd_5451_amnt_count': 9,
#  'mcc_cd_5462_amnt_count': 17,
#  'mcc_cd_5499_amnt_count': 130,
#  'mcc_cd_5511_amnt_count': 5,
#  'mcc_cd_5533_amnt_count': 22,
#  'mcc_cd_5541_amnt_count': 108,
#  'mcc_cd_5611_amnt_count': 1,
#  'mcc_cd_5621_amnt_count': 3,
#  'mcc_cd_5641_amnt_count': 29,
#  'mcc_cd_5651_amnt_count': 35,
#  'mcc_cd_5661_amnt_count': 3,
#  'mcc_cd_5691_amnt_count': 7,
#  'mcc_cd_5699_amnt_count': 1,
#  'mcc_cd_5712_amnt_count': 6,
#  'mcc_cd_5719_amnt_count': 2,
#  'mcc_cd_5722_amnt_count': 7,
#  'mcc_cd_5732_amnt_count': 6,
#  'mcc_cd_5812_amnt_count': 22,
#  'mcc_cd_5813_amnt_count': 21,
#  'mcc_cd_5814_amnt_count': 253,
#  'mcc_cd_5912_amnt_count': 73,
#  'mcc_cd_5921_amnt_count': 221,
#  'mcc_cd_5942_amnt_count': 1,
#  'mcc_cd_5943_amnt_count': 2,
#  'mcc_cd_5944_amnt_count': 1,
#  'mcc_cd_5945_amnt_count': 46,
#  'mcc_cd_5947_amnt_count': 2,
#  'mcc_cd_5949_amnt_count': 10,
#  'mcc_cd_5964_amnt_count': 7,
#  'mcc_cd_5977_amnt_count': 47,
#  'mcc_cd_5992_amnt_count': 5,
#  'mcc_cd_5995_amnt_count': 5,
#  'mcc_cd_5999_amnt_count': 13,
#  'mcc_cd_6010_amnt_count': 1,
#  'mcc_cd_6011_amnt_count': 97,
#  'mcc_cd_6536_amnt_count': 41,
#  'mcc_cd_6538_amnt_count': 3,
#  'mcc_cd_7011_amnt_count': 1,
#  'mcc_cd_7230_amnt_count': 6,
#  'mcc_cd_7299_amnt_count': 1,
#  'mcc_cd_7538_amnt_count': 1,
#  'mcc_cd_7542_amnt_count': 1,
#  'mcc_cd_7832_amnt_count': 3,
#  'mcc_cd_8043_amnt_count': 4,
#  'mcc_cd_8999_amnt_count': 3,
#  'mcc_cd_9222_amnt_count': 3,
#  'mcc_cd_9311_amnt_count': 2,
#  'mcc_cd_9402_amnt_count': 1,
#  'mcc_cd_-1_amnt_min': 42.0,
#  'mcc_cd_4111_amnt_min': 55.0,
#  'mcc_cd_4112_amnt_min': 50.0,
#  'mcc_cd_4121_amnt_min': 36.0,
#  'mcc_cd_4215_amnt_min': 455.0,
#  'mcc_cd_4812_amnt_min': 52.0,
#  'mcc_cd_5200_amnt_min': 36.0,
#  'mcc_cd_5211_amnt_min': 30.0,
#  'mcc_cd_5311_amnt_min': 33.0,
#  'mcc_cd_5331_amnt_min': 30.0,
#  'mcc_cd_5399_amnt_min': 114.0,
#  'mcc_cd_5411_amnt_min': 6.0,
#  'mcc_cd_5422_amnt_min': 102.0,
#  'mcc_cd_5441_amnt_min': 41.0,
#  'mcc_cd_5451_amnt_min': 107.0,
#  'mcc_cd_5462_amnt_min': 34.0,
#  'mcc_cd_5499_amnt_min': 21.0,
#  'mcc_cd_5511_amnt_min': 109.0,
#  'mcc_cd_5533_amnt_min': 73.0,
#  'mcc_cd_5541_amnt_min': 120.0,
#  'mcc_cd_5611_amnt_min': 134.0,
#  'mcc_cd_5621_amnt_min': 121.0,
#  'mcc_cd_5641_amnt_min': 1.0,
#  'mcc_cd_5651_amnt_min': 242.0,
#  'mcc_cd_5661_amnt_min': 2306.0,
#  'mcc_cd_5691_amnt_min': 682.0,
#  'mcc_cd_5699_amnt_min': 1820.0,
#  'mcc_cd_5712_amnt_min': 219.0,
#  'mcc_cd_5719_amnt_min': 1129.0,
#  'mcc_cd_5722_amnt_min': 36.0,
#  'mcc_cd_5732_amnt_min': 107.0,
#  'mcc_cd_5812_amnt_min': 72.0,
#  'mcc_cd_5813_amnt_min': 279.0,
#  'mcc_cd_5814_amnt_min': 2.0,
#  'mcc_cd_5912_amnt_min': 18.0,
#  'mcc_cd_5921_amnt_min': 18.0,
#  'mcc_cd_5942_amnt_min': 243.0,
#  'mcc_cd_5943_amnt_min': 73.0,
#  'mcc_cd_5944_amnt_min': 668.0,
#  'mcc_cd_5945_amnt_min': 5.0,
#  'mcc_cd_5947_amnt_min': 121.0,
#  'mcc_cd_5949_amnt_min': 24.0,
#  'mcc_cd_5964_amnt_min': 67.0,
#  'mcc_cd_5977_amnt_min': 33.0,
#  'mcc_cd_5992_amnt_min': 158.0,
#  'mcc_cd_5995_amnt_min': 87.0,
#  'mcc_cd_5999_amnt_min': 24.0,
#  'mcc_cd_6010_amnt_min': 1916.0,
#  'mcc_cd_6011_amnt_min': 121.0,
#  'mcc_cd_6536_amnt_min': 73.0,
#  'mcc_cd_6538_amnt_min': 1481.0,
#  'mcc_cd_7011_amnt_min': 2950.0,
#  'mcc_cd_7230_amnt_min': 425.0,
#  'mcc_cd_7299_amnt_min': 243.0,
#  'mcc_cd_7538_amnt_min': 656.0,
#  'mcc_cd_7542_amnt_min': 121.0,
#  'mcc_cd_7832_amnt_min': 182.0,
#  'mcc_cd_8043_amnt_min': 243.0,
#  'mcc_cd_8999_amnt_min': 459.0,
#  'mcc_cd_9222_amnt_min': 307.0,
#  'mcc_cd_9311_amnt_min': 1.0,
#  'mcc_cd_9402_amnt_min': 129.0,
#  'mcc_cd_-1_amnt_max': 6702.0,
#  'mcc_cd_4111_amnt_max': 67.0,
#  'mcc_cd_4112_amnt_max': 14565.0,
#  'mcc_cd_4121_amnt_max': 923.0,
#  'mcc_cd_4215_amnt_max': 1343.0,
#  'mcc_cd_4812_amnt_max': 16998.0,
#  'mcc_cd_5200_amnt_max': 4576.0,
#  'mcc_cd_5211_amnt_max': 1811.0,
#  'mcc_cd_5311_amnt_max': 1290.0,
#  'mcc_cd_5331_amnt_max': 1559.0,
#  'mcc_cd_5399_amnt_max': 4016.0,
#  'mcc_cd_5411_amnt_max': 4540.0,
#  'mcc_cd_5422_amnt_max': 322.0,
#  'mcc_cd_5441_amnt_max': 1227.0,
#  'mcc_cd_5451_amnt_max': 237.0,
#  'mcc_cd_5462_amnt_max': 958.0,
#  'mcc_cd_5499_amnt_max': 2185.0,
#  'mcc_cd_5511_amnt_max': 5162.0,
#  'mcc_cd_5533_amnt_max': 20228.0,
#  'mcc_cd_5541_amnt_max': 3692.0,
#  'mcc_cd_5611_amnt_max': 134.0,
#  'mcc_cd_5621_amnt_max': 474.0,
#  'mcc_cd_5641_amnt_max': 3255.0,
#  'mcc_cd_5651_amnt_max': 18501.0,
#  'mcc_cd_5661_amnt_max': 3095.0,
#  'mcc_cd_5691_amnt_max': 7285.0,
#  'mcc_cd_5699_amnt_max': 1820.0,
#  'mcc_cd_5712_amnt_max': 3519.0,
#  'mcc_cd_5719_amnt_max': 6355.0,
#  'mcc_cd_5722_amnt_max': 29127.0,
#  'mcc_cd_5732_amnt_max': 7284.0,
#  'mcc_cd_5812_amnt_max': 6872.0,
#  'mcc_cd_5813_amnt_max': 304.0,
#  'mcc_cd_5814_amnt_max': 2076.0,
#  'mcc_cd_5912_amnt_max': 1553.0,
#  'mcc_cd_5921_amnt_max': 2223.0,
#  'mcc_cd_5942_amnt_max': 243.0,
#  'mcc_cd_5943_amnt_max': 95.0,
#  'mcc_cd_5944_amnt_max': 668.0,
#  'mcc_cd_5945_amnt_max': 9067.0,
#  'mcc_cd_5947_amnt_max': 583.0,
#  'mcc_cd_5949_amnt_max': 1821.0,
#  'mcc_cd_5964_amnt_max': 542.0,
#  'mcc_cd_5977_amnt_max': 7101.0,
#  'mcc_cd_5992_amnt_max': 1578.0,
#  'mcc_cd_5995_amnt_max': 1703.0,
#  'mcc_cd_5999_amnt_max': 2805.0,
#  'mcc_cd_6010_amnt_max': 1916.0,
#  'mcc_cd_6011_amnt_max': 82803.0,
#  'mcc_cd_6536_amnt_max': 12141.0,
#  'mcc_cd_6538_amnt_max': 11593.0,
#  'mcc_cd_7011_amnt_max': 2950.0,
#  'mcc_cd_7230_amnt_max': 668.0,
#  'mcc_cd_7299_amnt_max': 243.0,
#  'mcc_cd_7538_amnt_max': 656.0,
#  'mcc_cd_7542_amnt_max': 121.0,
#  'mcc_cd_7832_amnt_max': 692.0,
#  'mcc_cd_8043_amnt_max': 877.0,
#  'mcc_cd_8999_amnt_max': 583.0,
#  'mcc_cd_9222_amnt_max': 643.0,
#  'mcc_cd_9311_amnt_max': 1957.0,
#  'mcc_cd_9402_amnt_max': 129.0,
#  'mcc_cd_-1_amnt_std': 1040.5686745288126,
#  'mcc_cd_4111_amnt_std': 5.947135533400229,
#  'mcc_cd_4112_amnt_std': 8165.9800595723555,
#  'mcc_cd_4121_amnt_std': 250.1367816291909,
#  'mcc_cd_4215_amnt_std': 627.9108216936542,
#  'mcc_cd_4812_amnt_std': 2478.031509740203,
#  'mcc_cd_5200_amnt_std': 1198.2741570210949,
#  'mcc_cd_5211_amnt_std': 323.300151543404,
#  'mcc_cd_5311_amnt_std': 240.9958632039944,
#  'mcc_cd_5331_amnt_std': 311.20698910301525,
#  'mcc_cd_5399_amnt_std': 1504.3262661907872,
#  'mcc_cd_5411_amnt_std': 493.77254469990675,
#  'mcc_cd_5422_amnt_std': 117.38966450813861,
#  'mcc_cd_5441_amnt_std': 265.43933790089056,
#  'mcc_cd_5451_amnt_std': 40.29819405934271,
#  'mcc_cd_5462_amnt_std': 227.38361599624852,
#  'mcc_cd_5499_amnt_std': 268.92905176592757,
#  'mcc_cd_5511_amnt_std': 2051.6357620201497,
#  'mcc_cd_5533_amnt_std': 4261.940785066266,
#  'mcc_cd_5541_amnt_std': 818.3589376917473,
#  'mcc_cd_5611_amnt_std': 0.0,
#  'mcc_cd_5621_amnt_std': 196.98477098496727,
#  'mcc_cd_5641_amnt_std': 660.6763346842557,
#  'mcc_cd_5651_amnt_std': 3545.3109775774387,
#  'mcc_cd_5661_amnt_std': 436.4794764170857,
#  'mcc_cd_5691_amnt_std': 2311.5459370403214,
#  'mcc_cd_5699_amnt_std': 0.0,
#  'mcc_cd_5712_amnt_std': 1249.6243702275763,
#  'mcc_cd_5719_amnt_std': 3695.3400384808974,
#  'mcc_cd_5722_amnt_std': 10547.828914498177,
#  'mcc_cd_5732_amnt_std': 3044.986808947892,
#  'mcc_cd_5812_amnt_std': 1687.1107375310728,
#  'mcc_cd_5813_amnt_std': 12.440333788202999,
#  'mcc_cd_5814_amnt_std': 320.6929223354287,
#  'mcc_cd_5912_amnt_std': 335.0081242341623,
#  'mcc_cd_5921_amnt_std': 325.2158692001313,
#  'mcc_cd_5942_amnt_std': 0.0,
#  'mcc_cd_5943_amnt_std': 15.556349186104045,
#  'mcc_cd_5944_amnt_std': 0.0,
#  'mcc_cd_5945_amnt_std': 1595.287338163363,
#  'mcc_cd_5947_amnt_std': 326.683332908185,
#  'mcc_cd_5949_amnt_std': 628.4138851991664,
#  'mcc_cd_5964_amnt_std': 209.57644360539595,
#  'mcc_cd_5977_amnt_std': 1259.3447718532361,
#  'mcc_cd_5992_amnt_std': 653.8789643351436,
#  'mcc_cd_5995_amnt_std': 696.1611164091255,
#  'mcc_cd_5999_amnt_std': 911.531220895185,
#  'mcc_cd_6010_amnt_std': 0.0,
#  'mcc_cd_6011_amnt_std': 9414.48255384533,
#  'mcc_cd_6536_amnt_std': 2490.1276416985575,
#  'mcc_cd_6538_amnt_std': 5838.165922045496,
#  'mcc_cd_7011_amnt_std': 0.0,
#  'mcc_cd_7230_amnt_std': 101.59461928009115,
#  'mcc_cd_7299_amnt_std': 0.0,
#  'mcc_cd_7538_amnt_std': 0.0,
#  'mcc_cd_7542_amnt_std': 0.0,
#  'mcc_cd_7832_amnt_std': 294.44863728670913,
#  'mcc_cd_8043_amnt_std': 270.71187019904886,
#  'mcc_cd_8999_amnt_std': 65.2099174461472,
#  'mcc_cd_9222_amnt_std': 193.98969044771425,
#  'mcc_cd_9311_amnt_std': 1383.100864000887,
#  'mcc_cd_9402_amnt_std': 0.0,
#  'mcc_cd_-1_amnt_mean': 579.3492063492064,
#  'mcc_cd_4111_amnt_mean': 59.421052631578945,
#  'mcc_cd_4112_amnt_mean': 9468.666666666666,
#  'mcc_cd_4121_amnt_mean': 325.1333333333333,
#  'mcc_cd_4215_amnt_mean': 899.0,
#  'mcc_cd_4812_amnt_mean': 1048.8,
#  'mcc_cd_5200_amnt_mean': 723.6538461538462,
#  'mcc_cd_5211_amnt_mean': 256.8918918918919,
#  'mcc_cd_5311_amnt_mean': 294.758064516129,
#  'mcc_cd_5331_amnt_mean': 327.984126984127,
#  'mcc_cd_5399_amnt_mean': 1322.3333333333333,
#  'mcc_cd_5411_amnt_mean': 392.2986666666667,
#  'mcc_cd_5422_amnt_mean': 188.33333333333334,
#  'mcc_cd_5441_amnt_mean': 184.4,
#  'mcc_cd_5451_amnt_mean': 145.22222222222223,
#  'mcc_cd_5462_amnt_mean': 174.05882352941177,
#  'mcc_cd_5499_amnt_mean': 272.9,
#  'mcc_cd_5511_amnt_mean': 1668.6,
#  'mcc_cd_5533_amnt_mean': 1851.7272727272727,
#  'mcc_cd_5541_amnt_mean': 1112.4351851851852,
#  'mcc_cd_5611_amnt_mean': 134.0,
#  'mcc_cd_5621_amnt_mean': 247.0,
#  'mcc_cd_5641_amnt_mean': 473.82758620689657,
#  'mcc_cd_5651_amnt_mean': 3295.114285714286,
#  'mcc_cd_5661_amnt_mean': 2592.6666666666665,
#  'mcc_cd_5691_amnt_mean': 3130.5714285714284,
#  'mcc_cd_5699_amnt_mean': 1820.0,
#  'mcc_cd_5712_amnt_mean': 1480.6666666666667,
#  'mcc_cd_5719_amnt_mean': 3742.0,
#  'mcc_cd_5722_amnt_mean': 7778.142857142857,
#  'mcc_cd_5732_amnt_mean': 2217.3333333333335,
#  'mcc_cd_5812_amnt_mean': 1059.4545454545455,
#  'mcc_cd_5813_amnt_mean': 294.4761904761905,
#  'mcc_cd_5814_amnt_mean': 288.7154150197629,
#  'mcc_cd_5912_amnt_mean': 368.2054794520548,
#  'mcc_cd_5921_amnt_mean': 408.0452488687783,
#  'mcc_cd_5942_amnt_mean': 243.0,
#  'mcc_cd_5943_amnt_mean': 84.0,
#  'mcc_cd_5944_amnt_mean': 668.0,
#  'mcc_cd_5945_amnt_mean': 1050.6739130434783,
#  'mcc_cd_5947_amnt_mean': 352.0,
#  'mcc_cd_5949_amnt_mean': 359.7,
#  'mcc_cd_5964_amnt_mean': 224.42857142857142,
#  'mcc_cd_5977_amnt_mean': 691.468085106383,
#  'mcc_cd_5992_amnt_mean': 866.8,
#  'mcc_cd_5995_amnt_mean': 475.4,
#  'mcc_cd_5999_amnt_mean': 922.0,
#  'mcc_cd_6010_amnt_mean': 1916.0,
#  'mcc_cd_6011_amnt_mean': 4234.371134020618,
#  'mcc_cd_6536_amnt_mean': 2018.3170731707316,
#  'mcc_cd_6538_amnt_mean': 4851.666666666667,
#  'mcc_cd_7011_amnt_mean': 2950.0,
#  'mcc_cd_7230_amnt_mean': 485.6666666666667,
#  'mcc_cd_7299_amnt_mean': 243.0,
#  'mcc_cd_7538_amnt_mean': 656.0,
#  'mcc_cd_7542_amnt_mean': 121.0,
#  'mcc_cd_7832_amnt_mean': 352.0,
#  'mcc_cd_8043_amnt_mean': 613.75,
#  'mcc_cd_8999_amnt_mean': 509.3333333333333,
#  'mcc_cd_9222_amnt_mean': 419.0,
#  'mcc_cd_9311_amnt_mean': 979.0,
#  'mcc_cd_9402_amnt_mean': 129.0,
#  'mcc_category_0_amnt_sum': 35413.0,
#  'mcc_category_1_amnt_sum': 170486.0,
#  'mcc_category_2_amnt_sum': 412650.0,
#  'mcc_category_3_amnt_sum': 161839.0,
#  'mcc_category_4_amnt_sum': 169.0,
#  'mcc_category_6_amnt_sum': 120191.0,
#  'mcc_category_7_amnt_sum': 6470.0,
#  'mcc_category_8_amnt_sum': 100521.0,
#  'mcc_category_9_amnt_sum': 495735.0,
#  'mcc_category_10_amnt_sum': 8984.0,
#  'mcc_category_11_amnt_sum': 31956.0,
#  'mcc_category_12_amnt_sum': 70592.0,
#  'mcc_category_13_amnt_sum': 44845.0,
#  'mcc_category_14_amnt_sum': 1385.0,
#  'mcc_category_15_amnt_sum': 292.0,
#  'mcc_category_16_amnt_sum': 102537.0,
#  'mcc_category_17_amnt_sum': 9901.0,
#  'mcc_category_18_amnt_sum': 898.0,
#  'mcc_category_19_amnt_sum': 6370.0,
#  'mcc_category_20_amnt_sum': 31356.0,
#  'mcc_category_0_amnt_count': 53,
#  'mcc_category_1_amnt_count': 139,
#  'mcc_category_2_amnt_count': 98,
#  'mcc_category_3_amnt_count': 80,
#  'mcc_category_4_amnt_count': 1,
#  'mcc_category_6_amnt_count': 63,
#  'mcc_category_7_amnt_count': 11,
#  'mcc_category_8_amnt_count': 49,
#  'mcc_category_9_amnt_count': 1305,
#  'mcc_category_10_amnt_count': 8,
#  'mcc_category_11_amnt_count': 79,
#  'mcc_category_12_amnt_count': 88,
#  'mcc_category_13_amnt_count': 72,
#  'mcc_category_14_amnt_count': 5,
#  'mcc_category_15_amnt_count': 3,
#  'mcc_category_16_amnt_count': 296,
#  'mcc_category_17_amnt_count': 22,
#  'mcc_category_18_amnt_count': 1,
#  'mcc_category_19_amnt_count': 36,
#  'mcc_category_20_amnt_count': 4,
#  'mcc_category_0_amnt_min': 33.0,
#  'mcc_category_1_amnt_min': 73.0,
#  'mcc_category_2_amnt_min': 121.0,
#  'mcc_category_3_amnt_min': 1.0,
#  'mcc_category_4_amnt_min': 169.0,
#  'mcc_category_6_amnt_min': 36.0,
#  'mcc_category_7_amnt_min': 97.0,
#  'mcc_category_8_amnt_min': 1.0,
#  'mcc_category_9_amnt_min': 6.0,
#  'mcc_category_10_amnt_min': 121.0,
#  'mcc_category_11_amnt_min': 18.0,
#  'mcc_category_12_amnt_min': 5.0,
#  'mcc_category_13_amnt_min': 30.0,
#  'mcc_category_14_amnt_min': 85.0,
#  'mcc_category_15_amnt_min': 42.0,
#  'mcc_category_16_amnt_min': 2.0,
#  'mcc_category_17_amnt_min': 67.0,
#  'mcc_category_18_amnt_min': 898.0,
#  'mcc_category_19_amnt_min': 36.0,
#  'mcc_category_20_amnt_min': 50.0,
#  'mcc_category_0_amnt_max': 7101.0,
#  'mcc_category_1_amnt_max': 20228.0,
#  'mcc_category_2_amnt_max': 82803.0,
#  'mcc_category_3_amnt_max': 18501.0,
#  'mcc_category_4_amnt_max': 169.0,
#  'mcc_category_6_amnt_max': 29127.0,
#  'mcc_category_7_amnt_max': 2428.0,
#  'mcc_category_8_amnt_max': 12141.0,
#  'mcc_category_9_amnt_max': 4540.0,
#  'mcc_category_10_amnt_max': 3946.0,
#  'mcc_category_11_amnt_max': 1553.0,
#  'mcc_category_12_amnt_max': 9067.0,
#  'mcc_category_13_amnt_max': 6355.0,
#  'mcc_category_14_amnt_max': 668.0,
#  'mcc_category_15_amnt_max': 129.0,
#  'mcc_category_16_amnt_max': 6872.0,
#  'mcc_category_17_amnt_max': 1674.0,
#  'mcc_category_18_amnt_max': 898.0,
#  'mcc_category_19_amnt_max': 923.0,
#  'mcc_category_20_amnt_max': 14565.0,
#  'mcc_category_0_amnt_std': 1186.7102999444282,
#  'mcc_category_1_amnt_std': 1873.613382359934,
#  'mcc_category_2_amnt_std': 9368.756063937572,
#  'mcc_category_3_amnt_std': 2809.6960666918308,
#  'mcc_category_4_amnt_std': 0.0,
#  'mcc_category_6_amnt_std': 4567.569150062667,
#  'mcc_category_7_amnt_std': 668.7305613147672,
#  'mcc_category_8_amnt_std': 2708.203771730939,
#  'mcc_category_9_amnt_std': 464.35363260993796,
#  'mcc_category_10_amnt_std': 1270.7340960472977,
#  'mcc_category_11_amnt_std': 362.77357045541123,
#  'mcc_category_12_amnt_std': 1406.4142107072917,
#  'mcc_category_13_amnt_std': 1128.581530995812,
#  'mcc_category_14_amnt_std': 239.0052300682979,
#  'mcc_category_15_amnt_std': 48.08672720547047,
#  'mcc_category_16_amnt_std': 575.7155416277521,
#  'mcc_category_17_amnt_std': 414.32946141615685,
#  'mcc_category_18_amnt_std': 0.0,
#  'mcc_category_19_amnt_std': 205.35056359370913,
#  'mcc_category_20_amnt_std': 7421.5052830720715,
#  'mcc_category_0_amnt_mean': 668.1698113207547,
#  'mcc_category_1_amnt_mean': 1226.5179856115108,
#  'mcc_category_2_amnt_mean': 4210.714285714285,
#  'mcc_category_3_amnt_mean': 2022.9875,
#  'mcc_category_4_amnt_mean': 169.0,
#  'mcc_category_6_amnt_mean': 1907.7936507936508,
#  'mcc_category_7_amnt_mean': 588.1818181818181,
#  'mcc_category_8_amnt_mean': 2051.4489795918366,
#  'mcc_category_9_amnt_mean': 379.8735632183908,
#  'mcc_category_10_amnt_mean': 1123.0,
#  'mcc_category_11_amnt_mean': 404.50632911392404,
#  'mcc_category_12_amnt_mean': 802.1818181818181,
#  'mcc_category_13_amnt_mean': 622.8472222222222,
#  'mcc_category_14_amnt_mean': 277.0,
#  'mcc_category_15_amnt_mean': 97.33333333333333,
#  'mcc_category_16_amnt_mean': 346.4087837837838,
#  'mcc_category_17_amnt_mean': 450.04545454545456,
#  'mcc_category_18_amnt_mean': 898.0,
#  'mcc_category_19_amnt_mean': 176.94444444444446,
#  'mcc_category_20_amnt_mean': 7839.0}

# %%
def make_aggregates(df, verbose=False):
    df_grouped = df.groupby('client_id')
    if verbose:
        df_grouped = tqdm(df_grouped)
    
    with Pool(processes=NUM_THREADS) as pool:
        df_features = pool.starmap(create_transaction_features, df_grouped, chunksize=100)
        df_features = pd.DataFrame(df_features)
        
    return df_features

# %%
from multiprocessing import Pool, cpu_count

# NUM_THREADS = cpu_count()
NUM_THREADS = 2

df_features = make_aggregates(df, verbose=True)
# Out:
#   0%|          | 0/11236 [00:00<?, ?it/s]
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/textor/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %%
df_features.head()
# Out:
#              client_id  num_transactions  num_weekofyear  num_days_tran_diff  \
# 0 -9220236243053692422               101              15                 129
# 1 -9220233431709087652               447              50                 357
# 2 -9219699286371310531                11              10                 275
# 3 -9218923580775423458                87              11                  98
# 4 -9218871523310554579                49              28                 327
#
#    num_days_tran_uniq  num_days_tran_median  num_days_tran_max  \
# 0                  33                 313.0                364
# 1                 182                 106.0                358
# 2                  10                 209.0                330
# 3                  43                 302.0                361
# 4                  38                 241.0                351
#
#    num_days_tran_std  hour_mean  hour_std  ...  mcc_cd_5261_amnt_min  \
# 0          37.008209  14.990099  4.398852  ...                   NaN
# 1         109.263280  10.939597  6.781234  ...                   NaN
# 2          90.733476   1.545455  5.125693  ...                   NaN
# 3          24.232573   5.701149  7.991442  ...                   NaN
# 4         101.262973  14.673469  5.014096  ...                   NaN
#
#    mcc_cd_5261_amnt_max  mcc_cd_5261_amnt_std  mcc_cd_5261_amnt_mean  \
# 0                   NaN                   NaN                    NaN
# 1                   NaN                   NaN                    NaN
# 2                   NaN                   NaN                    NaN
# 3                   NaN                   NaN                    NaN
# 4                   NaN                   NaN                    NaN
#
#    mcc_cd_5714_amnt_sum  mcc_cd_5714_amnt_count  mcc_cd_5714_amnt_min  \
# 0                   NaN                     NaN                   NaN
# 1                   NaN                     NaN                   NaN
# 2                   NaN                     NaN                   NaN
# 3                   NaN                     NaN                   NaN
# 4                   NaN                     NaN                   NaN
#
#    mcc_cd_5714_amnt_max  mcc_cd_5714_amnt_std  mcc_cd_5714_amnt_mean
# 0                   NaN                   NaN                    NaN
# 1                   NaN                   NaN                    NaN
# 2                   NaN                   NaN                    NaN
# 3                   NaN                   NaN                    NaN
# 4                   NaN                   NaN                    NaN
#
# [5 rows x 672 columns]

# %%
df_features.isna().sum(axis=0)
# Out:
# client_id                     0
# num_transactions              0
# num_weekofyear                0
# num_days_tran_diff            0
# num_days_tran_uniq            0
#                           ...
# mcc_cd_5714_amnt_count    10468
# mcc_cd_5714_amnt_min      10468
# mcc_cd_5714_amnt_max      10468
# mcc_cd_5714_amnt_std      10468
# mcc_cd_5714_amnt_mean     10468
# Length: 672, dtype: int64

# %%
df_features.columns[df_features.isna().sum(axis=0) > 0]
# Out:
# Index(['num_days_tran_std', 'hour_std', 'hour_diff_q50', 'hour_diff_max',
#        'hour_diff_std', 'weekend_amnt_mean', 'amnt_diff_q10', 'amnt_diff_q50',
#        'amnt_diff_q95', 'mcc_cd_4812_amnt_sum',
#        ...
#        'mcc_cd_5261_amnt_min', 'mcc_cd_5261_amnt_max', 'mcc_cd_5261_amnt_std',
#        'mcc_cd_5261_amnt_mean', 'mcc_cd_5714_amnt_sum',
#        'mcc_cd_5714_amnt_count', 'mcc_cd_5714_amnt_min',
#        'mcc_cd_5714_amnt_max', 'mcc_cd_5714_amnt_std',
#        'mcc_cd_5714_amnt_mean'],
#       dtype='object', length=657)

# %%
counts = df_features.isna().sum(axis=0) / df_features.shape[0]
columns = df_features.columns[counts < 0.95]
columns
# Out:
# Index(['client_id', 'num_transactions', 'num_weekofyear', 'num_days_tran_diff',
#        'num_days_tran_uniq', 'num_days_tran_median', 'num_days_tran_max',
#        'num_days_tran_std', 'hour_mean', 'hour_std',
#        ...
#        'mcc_cd_5261_amnt_min', 'mcc_cd_5261_amnt_max', 'mcc_cd_5261_amnt_std',
#        'mcc_cd_5261_amnt_mean', 'mcc_cd_5714_amnt_sum',
#        'mcc_cd_5714_amnt_count', 'mcc_cd_5714_amnt_min',
#        'mcc_cd_5714_amnt_max', 'mcc_cd_5714_amnt_std',
#        'mcc_cd_5714_amnt_mean'],
#       dtype='object', length=672)

# %%
set(df_features.columns[counts >= 0.95].str.rsplit('_', 2).str[0])
# Out:
# set()

# %%
df_features.to_csv('trxn_features.csv', index=False)
